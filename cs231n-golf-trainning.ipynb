# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My\ Drive/cs231n-golf

import sys
sys.path.append('/content/drive/My Drive/cs231n-golf')
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/cs231n-golf

# %%
# %cp '/content/drive/My Drive/cs231n-golf/data.zip' /content
# %cd /content
# !unzip data.zip
# %ls '/content/data'
# %cd /content/drive/My\ Drive/cs231n-golf
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/augmented_data/noise_0.2/1315.mp4
#   inflating: data/augmented_data/noise_0.2/19.mp4
#   inflating: data/augmented_data/noise_0.2/859.mp4
#   inflating: data/augmented_data/noise_0.2/118.mp4
#   inflating: data/augmented_data/noise_0.2/656.mp4
#   inflating: data/augmented_data/noise_0.2/130.mp4
#   inflating: data/augmented_data/noise_0.2/124.mp4
#   inflating: data/augmented_data/noise_0.2/642.mp4
#   inflating: data/augmented_data/noise_0.2/905.mp4
#   inflating: data/augmented_data/noise_0.2/1249.mp4
#   inflating: data/augmented_data/noise_0.2/911.mp4
#   inflating: data/augmented_data/noise_0.2/939.mp4
#   inflating: data/augmented_data/noise_0.2/1275.mp4
#   inflating: data/augmented_data/noise_0.2/1261.mp4
#   inflating: data/augmented_data/noise_0.2/722.mp4
#   inflating: data/augmented_data/noise_0.2/736.mp4
#   inflating: data/augmented_data/noise_0.2/285.mp4
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 60.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 135.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 107.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 44.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 116.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !python train.py --model yolo --iterations=2000 --batch=8 --seqlen=256 --lr=0.001

# %%
# !ls data/augmented_data
# Out:
# channel_shuffle  horizonal_flip  noise_0.2  rotate_5

# %%
# !python tester.py --model=convnext-transformer2 --seqlen=6
# Out:
# 2025-06-05 04:29:57.464976: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749097797.485638   27458 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749097797.491888   27458 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-05 04:29:57.511260: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ---valll2--
# ...

# %%
#from google.colab import runtime
#runtime.unassign()
